# %%
l = [100, 400, -5, 600, -300]
print(l)
# Out:
# [100, 400, -5, 600, -300]

# %%
l.sort()
print(l)
# Out:
# [-300, -5, 100, 400, 600]

# %%
l.sort(reverse= False)
print(l)
# Out:
# [-300, -5, 100, 400, 600]

# %%
l.sort(reverse = True)
print(l)
# Out:
# [600, 400, 100, -5, -300]

# %%
l1 = [200, 300, -300, 100, 600, 700]
print(l1)
# Out:
# [200, 300, -300, 100, 600, 700]

# %%
print(l+l1)
# Out:
# [600, 400, 100, -5, -300, 200, 300, -300, 100, 600, 700]

# %%
print(l)
l.index(-5)
# Out:
# [600, 400, 100, -5, -300]
# 3

# %%
l = [1, 2, 3]
l1= [1, 2, 3]
print(l)
print(l1)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
print(id(l))
print(id(l1))
# Out:
# 136703579331456
# 136703960283072

# %%
t = (1,2,3)
t1 = (1,2,3)
print(id(t))
print(id(t1))
# Out:
# 136703952188160
# 136703579330240

# %%
print(l is l1)
# Out:
# False

# %%
print(l==l1)
# Out:
# True

# %% [markdown]
# TUPLE

# %%
t = (1,2,3,-1,4)
print(t)
print(type(t))
# Out:
# (1, 2, 3, -1, 4)
# <class 'tuple'>

# %%
t1 = ()
print(t1)
print(type(t1))
# Out:
# ()
# <class 'tuple'>

# %%
t2 = (1)
print(t2)
print(type(t2))
# Out:
# 1
# <class 'int'>

# %%
t3 = 1,2,3
print(t3)
print(type(t3))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %% [markdown]
# How to put a single element in a tuple

# %%
t4=1,
print(t4)
print(type(t4))
# Out:
# (1,)
# <class 'tuple'>
